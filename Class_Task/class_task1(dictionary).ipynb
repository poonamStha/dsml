# %%
# create a dictionary to store student name,age and faculty
student ={
    'name':'ram',
    'age': 22,
    'faculty':'BEIT'
  }

# %%
student
# Out:
# {'name': 'ram', 'age': 22, 'faculty': 'BEIT'}

# %%
# add a new key called phone to an existing dictionary
student['phone']= 9898000000

# %%
student
# Out:
# {'name': 'ram', 'age': 22, 'faculty': 'BEIT', 'phone': 9898000000}

# %%
# update the value of age in a dictionary
# student['age']= 20 first method
# 2nd method
student1 ={
    'age' :20
}
student.update(student1)

# %%
student
# Out:
# {'name': 'ram', 'age': 20, 'faculty': 'BEIT', 'phone': 9898000000}

# %%
# Remove a key named city from a dictionary using del
student['city']='Kathmandu'
student
# Out:
# {'name': 'ram',
#  'age': 20,
#  'faculty': 'BEIT',
#  'phone': 9898000000,
#  'city': 'Kathmandu'}

# %%
del student['city']

# %%
student
# Out:
# {'name': 'ram', 'age': 20, 'faculty': 'BEIT', 'phone': 9898000000}

# %%
# check whether the key email exists in a dictionary
if 'email' in student:
  print("email is exist in dictonary")
else:
  print("email does not exist")
# Out:
# email does not exist
