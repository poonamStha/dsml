# %% [markdown]
# **Tuples**
# ![Screenshot 2026-06-13 202612.png](data:image/png;base64,...)

# %%
# eg of Tuples
data =(1,2,3,4,5)
type(data)
# Out:
# tuple

# %%
tuple((1,2,"hari",[8,5,6],5.6))
# Out:
# (1, 2, 'hari', [8, 5, 6], 5.6)

# %% [markdown]
# **Tuple Function**
# ![Screenshot 2026-06-13 203358.png](data:image/png;base64,...)

# %%
# eg of tuple function
data1 = (1,2,3,4,5)

# %%
len(data1)
# Out:
# 5

# %%
sum(data1)
# Out:
# 15

# %%
max(data1)
# Out:
# 5

# %%
min(data1)
# Out:
# 1

# %%
any(data1)
# Out:
# True

# %%
all(data1)
# Out:
# True

# %%
sorted(data1)
# Out:
# [1, 2, 3, 4, 5]

# %%
tuple(data1)
# Out:
# (1, 2, 3, 4, 5)

# %%
# unpacking tuples
data = (1,3,4)
a,b,c = data

# %%
a
# Out:
# 1

# %%
b
# Out:
# 3

# %%
c
# Out:
# 4

# %%
data = (1,2,3)
l, b, _ = data #blank space(_) for unwanted data
print(l)
print(b)
# Out:
# 1
# 2

# %% [markdown]
# **Tuple operations**
# ![Screenshot 2026-06-13 205833.png](data:image/png;base64,...)![Screenshot 2026-06-13 205826.png](data:image/png;base64,...)![Screenshot 2026-06-13 205819.png](data:image/png;base64,...)![Screenshot 2026-06-13 205435.png](data:image/png;base64,...)![Screenshot 2026-06-13 205423.png](data:image/png;base64,...)![Screenshot 2026-06-13 205416.png](data:image/png;base64,...)

# %%
# eg pf indexing
t = (10,20,30)
print(t[1])
# Out:
# 20

# %%
# eg of slicing
t = (10,20,30,40)
print(t[1:3])
# Out:
# (20, 30)

# %%
# eg of concatenation
t1 = (1, 2)
t2 =(3, 4)
print(t1+t2)
# Out:
# (1, 2, 3, 4)

# %%
# eg of repetitions
t = (1,2)
print(t*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
# eg of membership in tuples
t = (10,20,30)
print(20 in t)
# Out:
# True

# %%
# eg of comparison
t1 = (1,2)
t2 = (1,3)
print(t1<t2)
# Out:
# True

# %%
del data1
# can't delete individual elements in
# a tuple but whole tuples can delete
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10515/2744692550.py in <cell line: 0>()
# ----> 1 del data1
#       2 # can't delete individual elements in
#       3 # a tuple but whole tuples can delete
#
# NameError: name 'data1' is not defined

# %% [markdown]
# **Sets**
# ![Screenshot 2026-06-13 210722.png](data:image/png;base64,...)

# %%
dataset = {2,3,4,6}
print(type(dataset))
# Out:
# <class 'set'>

# %%
data ={}
print(type(data))
# Out:
# <class 'dict'>

# %%
set({"hello",123})
# Out:
# {123, 'hello'}

# %% [markdown]
# **Set Operation**
# ![Screenshot 2026-06-13 211329.png](data:image/png;base64,...)![Screenshot 2026-06-13 211410.png](data:image/png;base64,...)![Screenshot 2026-06-13 211354.png](data:image/png;base64,...)

# %%
# eg of union operation
A = {1,2,3}
B = {3,4,5}
print(A|B)
# Out:
# {1, 2, 3, 4, 5}

# %%
# eg of intersection
A = {1,2,3}
B = {2,3,4}
print(A&B)
# Out:
# {2, 3}

# %%
# eg of difference
A = {1,2,3}
B = {2,4}
print(A-B)
# Out:
# {1, 3}

# %%
# eg of symmetric difference
A = {1,2,3}
B = {3,4,5}
print(A^B)
# Out:
# {1, 2, 4, 5}

# %%
# eg of membership
A ={1,2,3}
print(2 in A)
# Out:
# True

# %%
# eg od subset(<=)
A ={1,2}
B ={1,2,3}
print(A<=B)
# Out:
# True
