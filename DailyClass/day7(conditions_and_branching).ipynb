# %% [markdown]
# **Conditions**
#
# ![Screenshot 2026-06-16 210345.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 210452.png](data:image/png;base64,...)

# %% [markdown]
# **branching in python**
#
# ![Screenshot 2026-06-16 210611.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 210623.png](data:image/png;base64,...)

# %%
# eg of if statement
age = int(input("Enter a age:"))
if age > 18:
  print("age")
# Out:
# Enter a age:12

# %% [markdown]
# ![Screenshot 2026-06-16 210643.png](data:image/png;base64,...)

# %%
# eg of if else statement
age = int(input("Enter a age:"))
if age > 18:
  print("age")
else:
  print("not eligible")
# Out:
# Enter a age:10
# not eligible

# %% [markdown]
# ![Screenshot 2026-06-16 210716.png](data:image/png;base64,...)

# %%
# eg of if elif else statement
age = int(input("enter your age:"))
if age < 18:
  print(" below 18")
elif age >= 18 and age <= 40:
  print("between 18 and 40")
else:
  print("above 40")
# Out:
# enter your age:25
# between 18 and 40

# %%
age = int(input("enter your age:"))
if age >= 18:
  Citizenship =input("do you have a citizenship(yes/no)")
  if Citizenship.lower() == "yes":
    print("eligible to vote")
  else:
    print("not valid to vote")
else:
  print("not valid to vote")
# Out:
# enter your age:25
# do you have a citizenship(yes/no)yes
# eligible to vote

# %% [markdown]
# ![Screenshot 2026-06-16 210732.png](data:image/png;base64,...)

# %%
# eg of nested condition
age = 25
if age <= 12:
  print("Child")
elif age <= 35:
  print("Teenager")
elif age<= 35:
  print("Youth adult")
else:
  print("Adult")
# Out:
# Teenager

# %% [markdown]
# **Ternary operator in python**
#
# ![Screenshot 2026-06-16 212652.png](data:image/png;base64,...)

# %%
num = int(input("enter a number"))
if num % 2 == 0:
  print("even")
else:
  print("odd")
# Out:
# enter a number1
# odd

# %%
#list comprehension
num = int(input("enter a number"))
res = "even" if num % 2 == 0 else "odd"
res
# Out:
# enter a number12
# 'even'

# %%
age = int(input("enter your age:"))
if  age >= 40:
  membership= input("membership(true/false):")
  if membership == "true":
    print("60% discount")
  else:
    print("40% discount")
else:
  print("remaining no disount")
# Out:
# enter your age:48
# membership(true/false):true
# 60% discount

# %%
lst =[3,4,6,7,9]
num = int(input("enter a number:"))
if num % 2 ==0:
  lst.append(num)
  print(lst)
else:
  lst.pop()
  print(lst)
# Out:
# enter a number:1
# [3, 4, 6, 7]

# %% [markdown]
# ![Screenshot 2026-06-16 213229.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-06-16 213312.png](data:image/png;base64,...)

# %%
# eg of and operator
age = 20
citizen = True
if age >= 18 and citizen:
  print("eligible to vote")
# Out:
# eligible to vote

# %%
# eg of or operator
username = "admin"
password ="1234"

if username == "admin" or password =="admin123":
  print("Access granted")
# Out:
# Access granted

# %%
# eg of not operator
is_logged_in = False
if not is_logged_in:
  print("please log in first")
# Out:
# please log in first
