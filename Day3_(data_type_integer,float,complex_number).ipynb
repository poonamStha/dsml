# %%
number =122
print(type(number))
# Out:
# <class 'int'>

# %% [markdown]
# Type: integer,float ra complex number
# 1.  we used type function
# 2.  integer is positive and negative
# 3. its representation is large and
# small

# %%
num = 3.4
type(num)
# Out:
# float

# %% [markdown]
# -this is example of float

# %%
com = 3+3j
type(com)
# Out:
# complex

# %% [markdown]
# *   this is example of complex
# *   we use this when we don't want floating number (give integer number like date of birth,age)

# %%
a = 3.45
b = int(a)
b
# Out:
# 3

# %% [markdown]
# **type conversion**
# -floating number convert into integer

# %%
a = 40
b = 20
print (a+b) #addition
print (a-b) #subtraction
print (a*b)   #multiplication
print (a/b) #dividion
print (a**2)  #
print (a%6)   #modulus
print (a//9)  #floor division
# Out:
# 60
# 20
# 800
# 2.0
# 1600
# 4
# 4

# %% [markdown]
# **this is example of arithmetic operation**

# %%
a = 10
b = 5
print (a == b)
print (a != b)
print (a > b)
print (a < b)
print (a >= b)
print (a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# **this is comparision operator**
# -it is condition and it gives value in boolean

# %%
import math
print(math.ceil(44.5))
print(math.floor(44.9))
print(math.gcd(3,6,9,12))
round(22.542,2)
user =60
capacity = 128
result =min(user,capacity)
# Out:
# 45
# 44
# 3

# %% [markdown]
# math function
# *  here we see math functions and when we wrrite math. shows list of math function operates(like: ceil,floor,gcd)

# %%
ab = "hello"
bc = 'hello'
print(ab ==bc)
# Out:
# True

# %% [markdown]
# **string**
#
#
# *   sequence of charecter
# *   text data store
# * single and double quote ma define
# * positive index start with zero
# * negative index start with -1

# %%
text1= "It's a sunny day"
text2 = 'He said "hello"'
print(text1)
print(text2)
# Out:
# It's a sunny day
# He said "hello"

# %% [markdown]
# single quotation ma chaiyo vani double quotation use garni,ani double quotation ma chaiyo vani single quotation use garni.

# %%
print(text1 +" "+ text2)#concatination
# Out:
# It's a sunny day He said "hello"

# %%
print(text1*3)#repetation
# Out:
# It's a sunny dayIt's a sunny dayIt's a sunny day

# %%
data = "python"
print(data[5])
print(data[-1])
# Out:
# n
# n

# %% [markdown]
# this is indexing example

# %%
#data[start:end:step]
print(data[1:4])
print(data[1:4:2])
print(data[:3])
print(data[:-1])
# Out:
# yth
# yh
# pyt
# pytho

# %% [markdown]
# **this is example of slicing.**

# %%
data1 = "hello python"
data1[1:-1]
# Out:
# 'ello pytho'

# %%
len(data1)
# Out:
# 12

# %% [markdown]
# it counts data length

# %%
data2 ="  I am a girl"
data3 ="I am a boy"
print(data2.replace("girl","boy"))
print(data2.upper())
print(data3.lower())
print(data2.title())
print(data2.strip())
print(data2.split())
# Out:
#   I am a boy
#   I AM A GIRL
# i am a boy
#   I Am A Girl
# I am a girl
# ['I', 'am', 'a', 'girl']

# %% [markdown]
# replace data

# %%
data5 ="image.png"

# %%
data5.endwith("png")
data5.startwith()

# %% [markdown]
# to check image type(like:png,jpg,jpeg)
